# %% [markdown]
# # Geocode providers with Geocodio

# %%
import pandas as pd
import numpy as np

from backend.models import handle_points
from backend.lib import geocoder

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
csv_path = '../../data/all_pcps_addresses.csv'
providers = handle_points.fetch_provider_addresses(csv_path)
# Out:
# There are 6157 unique addresses in this file.

# %%
addresses = list(providers.full_address)

# %%
geocodiocoder = geocoder.GeocodioCoder()
addresses.pop(2338) # This address raises a random 403 error

# %%
# Geocode the first 2500 due to Geocodio Limits
results = geocodiocoder.geocode_batch(addresses[:2499])

# %%
geocoded_df = pd.DataFrame(results, columns=['full_address', 'lat_long'])
# Out:
#                                         full_address                  lat_long
# 0          11441 HEACOCK ST, MORENO VALLEY, CA 92557  (33.958251, -117.244066)
# 1         2195 CLUB CTR DR, SAN BERNARDINO, CA 92408    (34.0947, -117.259667)
# 2          12401 WASHINGTON BLVD, WHITTIER, CA 90602   (33.969794, -118.04936)
# 3            701 PLEASANT GROVE, ROSEVILLE, CA 95678  (38.753484, -121.295594)
# 4                    1004 14TH AVE, DELANO, CA 93215  (35.774352, -119.245449)
# 5                1541 FLORIDA AVE, MODESTO, CA 95350  (37.666661, -120.996376)
# 6         39000 BOB HOPE DR, RANCHO MIRAGE, CA 92270  (33.764185, -116.407363)
# 7               4870 BARRANCA PKWY, IRVINE, CA 92604  (33.676314, -117.796052)
# 8          510 SUPERIOR AVE, NEWPORT BEACH, CA 92663   (33.624982, -117.93492)
# 9         15 E ARRELLAGA ST, SANTA BARBARA, CA 93101  (34.427344, -119.709543)
# 10         10884 SANTA MONICA BL, WESTWOOD, CA 90025    (34.049805, -118.4376)
# 11          1165 MONTGOMERY DR, SANTA ROSA, CA 95405   (38.443799, -122.70136)
# 12    3100 E FLORENCE AVE, HUNTINGTON PARK, CA 90255   (33.97256, -118.212374)
# 13         1601 MONTE VISTA AVE, CLAREMONT, CA 91711  (34.112238, -117.699295)
# 14         9645 MONTE VISTA AVE, MONTCLAIR, CA 91763  (34.080153, -117.697199)
# 15               1100 W STEWART DR, ORANGE, CA 92868   (33.78253, -117.865078)
# 16               845 W LA VETA AVE, ORANGE, CA 92868  (33.780729, -117.861396)
# 17     2700 E SLAUSON AVE, HUNTINGTON PARK, CA 90255  (33.988942, -118.222275)
# 18          3621 M L KING JR BLVD, LYNWOOD, CA 90262  (33.924538, -118.202954)
# 19          457 S LONG BEACH BLVD, COMPTON, CA 90221  (33.892671, -118.208192)
# 20               9840 IMPERIAL HWY, DOWNEY, CA 90242   (33.91693, -118.117648)
# 21            544 N GLENDALE AVE, GLENDALE, CA 91206  (34.154361, -118.242597)
# 22               1100 W STEWART DR, ORANGE, CA 92868   (33.78253, -117.865078)
# 23            1111 W LA PALMA AVE, ANAHEIM, CA 92801  (33.847285, -117.932542)
# 24              1201 W LA VETA AVE, ORANGE, CA 92868   (33.780472, -117.86587)
# 25         1107 S ALVARADO ST, LOS ANGELES, CA 90006   (34.05001, -118.281179)
# 26                    3851 SOTO ST, VERNON, CA 90058   (34.007157, -118.22083)
